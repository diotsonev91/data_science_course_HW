# %% [markdown]
# ## Problem 5 — Feature Manipulation
#
# This notebook builds a model-ready feature table from the cleaned dataset and previews the result.
# We use the reusable code in `src/features.py` (called via `build_features.py`).

# %%
# running script to build features
# !python ../src/build_features.py --in ../data/processed/asthma_clean.csv --outdir ../data/processed
# Out:
# Saved features to ../data/processed/features.csv and ../data/processed/target.csv  | X:(2392, 29) y:(2392,)

# %%
import pandas as pd

X = pd.read_csv("../data/processed/features.csv")
y = pd.read_csv("../data/processed/target.csv").squeeze("columns").astype(int)

print("Features shape:", X.shape)
print("Target shape:", y.shape)

display(X.head())
print("\nClass balance:")
print(y.value_counts(normalize=True).round(3))
# Out:
# Features shape: (2392, 29)
# Target shape: (2392,)
#         Age  Gender  Ethnicity  EducationLevel       BMI  Smoking
# 0  0.965740       0          1               0 -1.583956        0  \
# 1 -0.747054       1          2               2 -0.623674        0
# 2  0.687989       0          2               1 -1.229960        0
# 3 -0.098970       1          2               1  1.566787        0
# 4  0.873156       0          0               3 -1.106468        0
#
#    PhysicalActivity  DietQuality  SleepQuality  PollutionExposure  ...
# 0         -1.432857     0.160247      0.971811           0.809782  ...  \
# 1          0.291367     0.453343     -1.077424          -1.037492  ...
# 2          0.581572     1.435199     -0.102975          -1.211099  ...
# 3         -1.257069     0.276422     -1.597920          -1.510653  ...
# 4         -0.154204    -0.651878      1.506095          -1.374640  ...
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing
# ...
